# %%
import numpy as np
from clean_data import *
# Out:
# C:\Users\narot\Documents\GitHub\ML-Project\Code\clean_data.py:65: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# C:\Users\narot\Documents\GitHub\ML-Project\Code\clean_data.py:65: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# ...

# %%
G1_x_train , G1_x_test , G1_y_train , G1_y_test = student_G1_data()
G2_x_train , G2_x_test , G2_y_train , G2_y_test = student_G2_data()
G3_x_train , G3_x_test , G3_y_train , G3_y_test = student_G3_data()
